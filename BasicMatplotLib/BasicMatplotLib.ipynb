# %% [markdown]
# ## Intro to Matplotlib

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4,5],[2,3,7,5,6])
plt.show()

# %%
# Your data
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]

# Plotting
plt.plot(x, y, label="data" )
plt.xlabel("data")
plt.ylabel("random")
plt.title("random data")



# Customize x-axis ticks
plt.xticks([1, 2, 3, 4, 5], ['one', 'two', 'three', 'four', 'five'])

# Customize y-axis ticks
plt.yticks([2, 3, 4, 5, 6], ['two', 'three', 'four', 'five', 'six'])

# Display the plot
plt.show()
