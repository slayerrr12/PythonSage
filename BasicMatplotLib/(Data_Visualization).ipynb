# %% [markdown]
# ##  (Data Visualization)
#
# #### Topics
# 1. Matplotlib
#
#
# ##### Note:
# 1. First Clean the Evironment (Go to "Kernel" Menu --> "Restart & Clean Output"
# 2. To execute the code --> Click on a cell and press cntrl + enter key

# %% [markdown]
# # Data Visualization
# 1. Graphical representation of information and Data
# 2. Graph, Chart, and Map make it easier to understed the patterns in Data
#
# #  Matplotlib
# Matplotlib is an amazing visualization library in Python for 2D plots of arrays.
#
# ###  To Save image on your Machine
# plt.savefig("path\name")

# %% [markdown]
# #  Import matplotlib

# %%
#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %% [markdown]
# # **1 Line Plot**

# %% [markdown]
# ### 1.1 Plot a Line

# %%
x_values = [0,1,2,3,4,5]
squares = [0,1,4,9,16,25]
cubes = [0,1,8,27,64,125]
plt.grid()
plt.plot(x_values,squares)
# plt.show()
plt.plot(x_values,cubes)
#plot(x,y)
# plt.show()

plt.savefig("testimageMCA.jpg")

# %% [markdown]
# ### 1.2 Plot a Line with Details

# %%
A = [5,2,7]
B = [2,16,4]
plt.plot(A,B)
plt.show()
plt.title('Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.grid()
plt.show()

# %% [markdown]
# ### 1.3 Plot Multiple Lines

# %%
x = [1,2,3,4,5]
y = [50,40,70,80,20]
y2 = [80,20,20,50,60]
y3 = [70,20,60,40,60]
y4 = [80,20,20,50,60]
plt.plot(x,y4,'y',label='KTM',linewidth=10)
plt.plot(x,y,'g',label='Enfield', linewidth=5)

plt.plot(x,y2,'c',label='Honda',linewidth=5)
plt.plot(x,y3,'k',label='Yahama',linewidth=5)
#plt.plot(x,y4,'y',label='KTM',linewidth=5)
plt.title('bike details in line plot')
plt.ylabel('Distance in kms')
plt.xlabel('Days')
plt.legend()
#plt.grid()
#plt.savefig("multipleline.jpg")

# %% [markdown]
# # 2 Bar Plot

# %% [markdown]
# ### 2.1 Plot a Bar Chart

# %%
x_values = [5,6,3,7,2]
y_values = ["A", "B", "C", "D", "E"]
plt.bar(y_values,x_values)
#plt.show()
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### 2.2 Multiple Bar Plot

# %%
# Example 1
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],
label="Enfield",width=.5)
plt.bar([0.26,1.25,2.25,3.25,4.25],[80,20,20,50,60],
label="Honda", color='r',width=.5)
plt.show()
plt.bar([0.31,1.5,2.5,3.5,4.5],[70,20,60,40,60],
label="Yamaha", color='y',width=.5)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],
label="KTM", color='g',width=.5)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Bikes details in BAR PLOTTING')
# Out:
# Text(0.5, 1.0, 'Bikes details in BAR PLOTTING')

# %%
plt.bar(['A','B','C','D','E'],[50,40,70,80,20],
label="Enfield",width=.5)
plt.bar(['F','G','H','I','J'],[80,20,20,50,60],
label="Honda", color='r',width=.5)
plt.bar(['K','L','M','N','O'],[70,20,60,40,60],
label="Yamaha", color='y',width=.5)
plt.bar(['P','Q','R','S','T'],[80,20,20,50,60],
label="KTM", color='g',width=.5)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Bikes details in BAR PLOTTING')
# Out:
# Text(0.5, 1.0, 'Bikes details in BAR PLOTTING')

# %%
#Example 2
from matplotlib import pyplot as plt
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20], label="BMW")
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60], label="Audi")
plt.plot([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],label = "BMW",color = 'red')
plt.plot([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],label = "Audi",color = 'green')
plt.legend()
plt.grid()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Information')
plt.show()

# %% [markdown]
# ### 2.3 Horizontal Bar Plot

# %%
x_values = [5,6,3,7,2]
y_val = ["A", "B", "C", "D", "E"]

plt.barh(y_val,x_values, color ="yellowgreen")      # Adding an "h" after bar will flip the graph
plt.show()

# %% [markdown]
# # 3 Scatter Plot

# %% [markdown]
# ### 3.1 Scatter plot withhout Details

# %%
x = [5, 2, 9, 4, 7]     # x-axis values 

y = [10, 5, 8, 4, 2]         # Y-axis values 

plt.scatter(x, y)  
plt.grid()
# Function to plot scatter 

plt.show()               # function to show the plot

# %% [markdown]
# ### 3.2 Multiple Scatter Plot

# %%
x = [1,1.5,2,2.5,3,3.5,3.6]
y = [7.5,8,8.5,9,9.5,10,10.5]
x1=[8,8.5,9,9.5,10,10.5,11]
y1=[3,3.5,3.7,4,4.5,5,5.2]
plt.scatter(x,y, label='high income low saving',color='r')
plt.scatter(x1,y1,label='low income high savings',color='b')
plt.xlabel('saving*100')
plt.ylabel('income*1000')
plt.title('Scatter Plot')
plt.legend()
#plt.show()       
plt.grid()

# %% [markdown]
# # 4  pie plot

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4]

slices = [1+1+1,2+1+1,6+1+1,1+7+1]
activities = ['Enfield','Honda','Yahama','KTM']
cols = ['r','g','y','b']
labels=activities
colors=cols
#slices
plt.pie(slices, labels = labels , colors = cols , startangle=60, shadow= True,explode=(0,.2,0,0), autopct='%1.2f%%')

plt.title('Bike details in Pie Plot')
# Out:
# Text(0.5, 1.0, 'Bike details in Pie Plot')

# %% [markdown]
# ### 5 Matplotlib Plots on NBA DataSet

# %%
import pandas as pd
#import matplotlib.pyplot as plt

# %%
import os
import pandas as pd

# Get the current working directory
current_dir = os.getcwd()

# Specify the file path relative to the current directory
file_path = os.path.join(current_dir, 'nba.csv')

# Read the CSV file
df = pd.read_csv(file_path)

df
# Out:
#               Name            Team  Number Position   Age Height  Weight
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### 5.1 Bar Graph

# %%
#Example 1
y_values = df['Salary']
x_values = df['Age']
plt.xlabel('Age')                                   #To plot a bar graph plt.bar() command is used
plt.ylabel('Salary (in millions)')
plt.bar(x_values,y_values,color = "purple")          #This plots a bar graph between Age and Salaries of NBA players
plt.show()

# %%
# Example 2
y_values = df['Salary']
x_values = df['Age']
plt.xlabel('Age')                           #making changes in the color field changes the colour of the graph     
plt.ylabel('Salary (in millions)')                  
plt.bar(x_values,y_values,color = "khaki")          
plt.show()

# %% [markdown]
# ### 5.2 Horizontal Bar Graph

# %%
y_values = df['Salary']
x_values = df['Age']
plt.xlabel('Age')                                         
plt.ylabel('Salary (in millions)')
plt.barh(x_values,y_values,color = "indianred")           
plt.show()

# %% [markdown]
# ### 5.3 Scatter Plot

# %%
#Example 1
y_value=df['Salary']
x_values=df['Age']                  #To display a scatter plot we use plt.scatter() command 
plt.xlabel('Age')
plt.ylabel('Salary (in millions)')
plt.scatter(x_values,y_values)      #This displays a scatter plot between Age and Salaries of NBA players

# %%
#Example 2

y_value=df['Salary']
x_values=df['Age']
plt.xlabel('Age')
plt.ylabel('Salary (in millions)')
plt.scatter(x_values,y_values, color = "slategrey", marker = "X") #We can also change the type and colors of scatter plot as shown
